# %%
import numpy as np
import pandas as pd
from pathlib import Path
import glob 
import os
import matplotlib.pyplot as plt 
import matplotlib
from datetime import datetime
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
import gc
from sklearn import preprocessing

# %%
input_path = Path('/home/jovyan/workspace/amex-challenge/data')

# %%
train_data = pd.read_csv(
    input_path / 'train_data.csv',
    index_col='customer_ID')
train_data.to_feather(input_path / 'train_data.ftr')

# %%
ROWS=100000
train_data = pd.read_csv(
    input_path / 'train_data.csv',
    index_col='customer_ID', nrows=ROWS)

train_labels = pd.read_csv(input_path / 'train_labels.csv', index_col='customer_ID')

# %%
joined_data = train_data.join(train_labels, on="customer_ID")
joined_data
# Out:
#                                                            S_2       P_2  \
# customer_ID
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...  2017-03-09  0.938469
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...  2017-04-07  0.936665
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...  2017-05-28  0.954180
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...  2017-06-13  0.960384
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fb...  2017-07-16  0.947248
# ...                                                        ...       ...
# 049dd5e7b5a6895c4f8b179362d8e91f26ebf0b6c95e99e...  2018-01-02  0.458911
# 049dd5e7b5a6895c4f8b179362d8e91f26ebf0b6c95e99e...  2018-02-27  0.363298
# 049dd5e7b5a6895c4f8b179362d8e91f26ebf0b6c95e99e...  2018-03-08  0.356621
# 049e0948e285ec6767bf07e6e3f5e0919821ee200e359dc...  2017-03-29  0.714477
# 049e0948e285ec6767bf07e6e3f5e0919821ee200e359dc...  2017-04-28  0.614861
#
#                                                         D_39       B_1  \
# ...
